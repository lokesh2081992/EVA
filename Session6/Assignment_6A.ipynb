# %%
from keras import backend as K
import time
import matplotlib.pyplot as plt
import numpy as np
% matplotlib inline
np.random.seed(2017) 
from keras.models import Sequential
from keras.layers.convolutional import Convolution2D, MaxPooling2D
from keras.layers import Activation, Flatten, Dense, Dropout
from keras.layers.normalization import BatchNormalization
from keras.utils import np_utils
# Out:
# Using TensorFlow backend.

# %%
from keras.datasets import cifar10
(train_features, train_labels), (test_features, test_labels) = cifar10.load_data()
num_train, img_channels, img_rows, img_cols =  train_features.shape
num_test, _, _, _ =  test_features.shape
num_classes = len(np.unique(train_labels))
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170500096/170498071 [==============================] - 16s 0us/step

# %%
class_names = ['airplane','automobile','bird','cat','deer',
               'dog','frog','horse','ship','truck']
fig = plt.figure(figsize=(8,3))
for i in range(num_classes):
    ax = fig.add_subplot(2, 5, 1 + i, xticks=[], yticks=[])
    idx = np.where(train_labels[:]==i)[0]
    features_idx = train_features[idx,::]
    img_num = np.random.randint(features_idx.shape[0])
    im = features_idx[img_num]
    ax.set_title(class_names[i])
    plt.imshow(im)
plt.show()

# %%
def plot_model_history(model_history):
    fig, axs = plt.subplots(1,2,figsize=(15,5))
    # summarize history for accuracy
    axs[0].plot(range(1,len(model_history.history['acc'])+1),model_history.history['acc'])
    axs[0].plot(range(1,len(model_history.history['val_acc'])+1),model_history.history['val_acc'])
    axs[0].set_title('Model Accuracy')
    axs[0].set_ylabel('Accuracy')
    axs[0].set_xlabel('Epoch')
    axs[0].set_xticks(np.arange(1,len(model_history.history['acc'])+1),len(model_history.history['acc'])/10)
    axs[0].legend(['train', 'val'], loc='best')
    # summarize history for loss
    axs[1].plot(range(1,len(model_history.history['loss'])+1),model_history.history['loss'])
    axs[1].plot(range(1,len(model_history.history['val_loss'])+1),model_history.history['val_loss'])
    axs[1].set_title('Model Loss')
    axs[1].set_ylabel('Loss')
    axs[1].set_xlabel('Epoch')
    axs[1].set_xticks(np.arange(1,len(model_history.history['loss'])+1),len(model_history.history['loss'])/10)
    axs[1].legend(['train', 'val'], loc='best')
    plt.show()

# %%
def accuracy(test_x, test_y, model):
    result = model.predict(test_x)
    predicted_class = np.argmax(result, axis=1)
    true_class = np.argmax(test_y, axis=1)
    num_correct = np.sum(predicted_class == true_class) 
    accuracy = float(num_correct)/result.shape[0]
    return (accuracy * 100)

# %%
train_features = train_features.astype('float32')/255
test_features = test_features.astype('float32')/255
# convert class labels to binary class labels
train_labels = np_utils.to_categorical(train_labels, num_classes)
test_labels = np_utils.to_categorical(test_labels, num_classes)

# %%
# Define the model
model = Sequential()
model.add(Convolution2D(48, 3, 3, border_mode='same', input_shape=(32, 32, 3)))
model.add(Activation('relu'))
model.add(Convolution2D(48, 3, 3))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))
model.add(Convolution2D(96, 3, 3, border_mode='same'))
model.add(Activation('relu'))
model.add(Convolution2D(96, 3, 3))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))
model.add(Convolution2D(192, 3, 3, border_mode='same'))
model.add(Activation('relu'))
model.add(Convolution2D(192, 3, 3))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))
model.add(Flatten())
model.add(Dense(512))
model.add(Activation('relu'))
model.add(Dropout(0.5))
model.add(Dense(256))
model.add(Activation('relu'))
model.add(Dropout(0.5))
model.add(Dense(num_classes, activation='softmax'))
# Compile the model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:2: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(48, (3, 3), input_shape=(32, 32, 3..., padding="same")`
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:4: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(48, (3, 3))`
#   after removing the cwd from sys.path.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:8: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(96, (3, 3), padding="same")`
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:10: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(96, (3, 3))`
#   # Remove the CWD from sys.path while we load stuff.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:14: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(192, (3, 3), padding="same")`
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:16: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(192, (3, 3))`
#   app.launch_new_instance()

# %%
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 32, 32, 48)        1344
# _________________________________________________________________
# activation_1 (Activation)    (None, 32, 32, 48)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 30, 30, 48)        20784
# _________________________________________________________________
# activation_2 (Activation)    (None, 30, 30, 48)        0
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 15, 15, 48)        0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 15, 15, 48)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 15, 15, 96)        41568
# _________________________________________________________________
# activation_3 (Activation)    (None, 15, 15, 96)        0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 13, 13, 96)        83040
# _________________________________________________________________
# activation_4 (Activation)    (None, 13, 13, 96)        0
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 6, 6, 96)          0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 6, 6, 96)          0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 6, 6, 192)         166080
# _________________________________________________________________
# activation_5 (Activation)    (None, 6, 6, 192)         0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 4, 4, 192)         331968
# _________________________________________________________________
# activation_6 (Activation)    (None, 4, 4, 192)         0
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 2, 2, 192)         0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 2, 2, 192)         0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 768)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 512)               393728
# _________________________________________________________________
# activation_7 (Activation)    (None, 512)               0
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 256)               131328
# _________________________________________________________________
# activation_8 (Activation)    (None, 256)               0
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 10)                2570
# =================================================================
# Total params: 1,172,410
# Trainable params: 1,172,410
# Non-trainable params: 0
# _________________________________________________________________

# %%
from keras.preprocessing.image import ImageDataGenerator

datagen = ImageDataGenerator(zoom_range=0.0, 
                             horizontal_flip=False)


# train the model
start = time.time()
# Train the model
model_info = model.fit_generator(datagen.flow(train_features, train_labels, batch_size = 128),
                                 samples_per_epoch = train_features.shape[0], nb_epoch = 100, 
                                 validation_data = (test_features, test_labels), verbose=1)
end = time.time()
print ("Model took %0.2f seconds to train"%(end - start))
# plot model history
plot_model_history(model_info)
# compute test accuracy
print ("Accuracy on test data is: %0.2f"%accuracy(test_features, test_labels, model))
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:12: UserWarning: The semantics of the Keras 2 argument `steps_per_epoch` is not the same as the Keras 1 argument `samples_per_epoch`. `steps_per_epoch` is the number of batches to draw from the generator at each epoch. Basically steps_per_epoch = samples_per_epoch/batch_size. Similarly `nb_val_samples`->`validation_steps` and `val_samples`->`steps` arguments have changed. Update your method calls accordingly.
#   if sys.path[0] == '':
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:12: UserWarning: Update your `fit_generator` call to the Keras 2 API: `fit_generator(<keras_pre..., validation_data=(array([[[..., verbose=1, steps_per_epoch=390, epochs=100)`
#   if sys.path[0] == '':
# Epoch 1/100
# 390/390 [==============================] - 15s 38ms/step - loss: 1.8474 - acc: 0.2976 - val_loss: 1.4775 - val_acc: 0.4438
# Epoch 2/100
# 390/390 [==============================] - 9s 23ms/step - loss: 1.3388 - acc: 0.5138 - val_loss: 1.1650 - val_acc: 0.5836
# Epoch 3/100
# 390/390 [==============================] - 9s 23ms/step - loss: 1.1217 - acc: 0.6021 - val_loss: 0.9505 - val_acc: 0.6678
# Epoch 4/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.9821 - acc: 0.6570 - val_loss: 0.8783 - val_acc: 0.6931
# Epoch 5/100
# 390/390 [==============================] - 9s 22ms/step - loss: 0.8880 - acc: 0.6917 - val_loss: 0.7956 - val_acc: 0.7272
# Epoch 6/100
# 390/390 [==============================] - 9s 22ms/step - loss: 0.8120 - acc: 0.7185 - val_loss: 0.7481 - val_acc: 0.7457
# Epoch 7/100
# 390/390 [==============================] - 9s 22ms/step - loss: 0.7517 - acc: 0.7428 - val_loss: 0.7098 - val_acc: 0.7603
# Epoch 8/100
# 390/390 [==============================] - 9s 22ms/step - loss: 0.7101 - acc: 0.7558 - val_loss: 0.6706 - val_acc: 0.7698
# Epoch 9/100
# 390/390 [==============================] - 9s 22ms/step - loss: 0.6705 - acc: 0.7707 - val_loss: 0.6323 - val_acc: 0.7861
# Epoch 10/100
# 390/390 [==============================] - 9s 22ms/step - loss: 0.6371 - acc: 0.7811 - val_loss: 0.6042 - val_acc: 0.7937
# Epoch 11/100
# 390/390 [==============================] - 9s 22ms/step - loss: 0.6132 - acc: 0.7905 - val_loss: 0.6212 - val_acc: 0.7868
# Epoch 12/100
# 390/390 [==============================] - 9s 22ms/step - loss: 0.5904 - acc: 0.8003 - val_loss: 0.5966 - val_acc: 0.8039
# Epoch 13/100
# 390/390 [==============================] - 9s 22ms/step - loss: 0.5718 - acc: 0.8051 - val_loss: 0.6090 - val_acc: 0.7982
# Epoch 14/100
# 390/390 [==============================] - 9s 22ms/step - loss: 0.5539 - acc: 0.8118 - val_loss: 0.5901 - val_acc: 0.8042
# Epoch 15/100
# 390/390 [==============================] - 9s 22ms/step - loss: 0.5379 - acc: 0.8170 - val_loss: 0.6145 - val_acc: 0.7989
# Epoch 16/100
# 390/390 [==============================] - 9s 22ms/step - loss: 0.5152 - acc: 0.8243 - val_loss: 0.5736 - val_acc: 0.8121
# Epoch 17/100
# 390/390 [==============================] - 9s 22ms/step - loss: 0.5071 - acc: 0.8265 - val_loss: 0.5763 - val_acc: 0.8126
# Epoch 18/100
# 390/390 [==============================] - 9s 22ms/step - loss: 0.4908 - acc: 0.8316 - val_loss: 0.5998 - val_acc: 0.8048
# Epoch 19/100
# 390/390 [==============================] - 9s 22ms/step - loss: 0.4904 - acc: 0.8332 - val_loss: 0.5573 - val_acc: 0.8112
# Epoch 20/100
# 390/390 [==============================] - 9s 22ms/step - loss: 0.4800 - acc: 0.8379 - val_loss: 0.5650 - val_acc: 0.8141
# Epoch 21/100
# 390/390 [==============================] - 9s 22ms/step - loss: 0.4633 - acc: 0.8422 - val_loss: 0.5724 - val_acc: 0.8139
# Epoch 22/100
# 390/390 [==============================] - 9s 22ms/step - loss: 0.4551 - acc: 0.8445 - val_loss: 0.5925 - val_acc: 0.8113
# Epoch 23/100
# 390/390 [==============================] - 9s 22ms/step - loss: 0.4407 - acc: 0.8494 - val_loss: 0.5833 - val_acc: 0.8151
# Epoch 24/100
# 390/390 [==============================] - 9s 22ms/step - loss: 0.4446 - acc: 0.8489 - val_loss: 0.5694 - val_acc: 0.8180
# Epoch 25/100
# 390/390 [==============================] - 9s 22ms/step - loss: 0.4335 - acc: 0.8540 - val_loss: 0.5770 - val_acc: 0.8135
# Epoch 26/100
# 390/390 [==============================] - 9s 22ms/step - loss: 0.4267 - acc: 0.8545 - val_loss: 0.5669 - val_acc: 0.8180
# Epoch 27/100
# 390/390 [==============================] - 9s 22ms/step - loss: 0.4217 - acc: 0.8561 - val_loss: 0.5898 - val_acc: 0.8141
# Epoch 28/100
# 390/390 [==============================] - 9s 22ms/step - loss: 0.4104 - acc: 0.8609 - val_loss: 0.5574 - val_acc: 0.8220
# Epoch 29/100
# 390/390 [==============================] - 9s 22ms/step - loss: 0.4088 - acc: 0.8629 - val_loss: 0.5518 - val_acc: 0.8236
# Epoch 30/100
# 390/390 [==============================] - 9s 22ms/step - loss: 0.3980 - acc: 0.8646 - val_loss: 0.5559 - val_acc: 0.8284
# Epoch 31/100
# 390/390 [==============================] - 9s 22ms/step - loss: 0.3917 - acc: 0.8684 - val_loss: 0.5616 - val_acc: 0.8260
# Epoch 32/100
# 390/390 [==============================] - 9s 22ms/step - loss: 0.3843 - acc: 0.8686 - val_loss: 0.5542 - val_acc: 0.8273
# Epoch 33/100
# 390/390 [==============================] - 9s 22ms/step - loss: 0.3871 - acc: 0.8685 - val_loss: 0.5522 - val_acc: 0.8261
# Epoch 34/100
# 390/390 [==============================] - 9s 22ms/step - loss: 0.3776 - acc: 0.8735 - val_loss: 0.5542 - val_acc: 0.8199
# Epoch 35/100
# 390/390 [==============================] - 9s 22ms/step - loss: 0.3775 - acc: 0.8716 - val_loss: 0.5820 - val_acc: 0.8205
# Epoch 36/100
# 390/390 [==============================] - 9s 22ms/step - loss: 0.3707 - acc: 0.8742 - val_loss: 0.6057 - val_acc: 0.8226
# Epoch 37/100
# 390/390 [==============================] - 9s 22ms/step - loss: 0.3665 - acc: 0.8770 - val_loss: 0.5901 - val_acc: 0.8167
# Epoch 38/100
# 390/390 [==============================] - 9s 22ms/step - loss: 0.3584 - acc: 0.8767 - val_loss: 0.5687 - val_acc: 0.8259
# Epoch 39/100
# 390/390 [==============================] - 9s 22ms/step - loss: 0.3620 - acc: 0.8791 - val_loss: 0.5982 - val_acc: 0.8215
# Epoch 40/100
# 390/390 [==============================] - 9s 22ms/step - loss: 0.3657 - acc: 0.8779 - val_loss: 0.5648 - val_acc: 0.8270
# Epoch 41/100
# 390/390 [==============================] - 9s 22ms/step - loss: 0.3522 - acc: 0.8799 - val_loss: 0.5666 - val_acc: 0.8193
# Epoch 42/100
# 390/390 [==============================] - 9s 22ms/step - loss: 0.3505 - acc: 0.8802 - val_loss: 0.5655 - val_acc: 0.8285
# Epoch 43/100
# 390/390 [==============================] - 9s 22ms/step - loss: 0.3441 - acc: 0.8847 - val_loss: 0.5578 - val_acc: 0.8245
# Epoch 44/100
# 390/390 [==============================] - 9s 22ms/step - loss: 0.3398 - acc: 0.8866 - val_loss: 0.5712 - val_acc: 0.8267
# Epoch 45/100
# 390/390 [==============================] - 9s 22ms/step - loss: 0.3464 - acc: 0.8839 - val_loss: 0.5671 - val_acc: 0.8240
# Epoch 46/100
# 390/390 [==============================] - 9s 22ms/step - loss: 0.3400 - acc: 0.8855 - val_loss: 0.5737 - val_acc: 0.8271
# Epoch 47/100
# 390/390 [==============================] - 9s 22ms/step - loss: 0.3295 - acc: 0.8903 - val_loss: 0.6274 - val_acc: 0.8190
# Epoch 48/100
# 390/390 [==============================] - 9s 22ms/step - loss: 0.3378 - acc: 0.8876 - val_loss: 0.5833 - val_acc: 0.8267
# Epoch 49/100
# 390/390 [==============================] - 9s 22ms/step - loss: 0.3294 - acc: 0.8916 - val_loss: 0.5632 - val_acc: 0.8273
# Epoch 50/100
# 390/390 [==============================] - 9s 22ms/step - loss: 0.3211 - acc: 0.8932 - val_loss: 0.6185 - val_acc: 0.8181
# Epoch 51/100
# 390/390 [==============================] - 9s 22ms/step - loss: 0.3369 - acc: 0.8889 - val_loss: 0.5842 - val_acc: 0.8275
# Epoch 52/100
# 390/390 [==============================] - 9s 22ms/step - loss: 0.3212 - acc: 0.8912 - val_loss: 0.5970 - val_acc: 0.8197
# Epoch 53/100
# 390/390 [==============================] - 9s 22ms/step - loss: 0.3238 - acc: 0.8928 - val_loss: 0.5811 - val_acc: 0.8328
# Epoch 54/100
# 390/390 [==============================] - 9s 22ms/step - loss: 0.3132 - acc: 0.8955 - val_loss: 0.5674 - val_acc: 0.8353
# Epoch 55/100
# 390/390 [==============================] - 9s 22ms/step - loss: 0.3135 - acc: 0.8952 - val_loss: 0.5972 - val_acc: 0.8257
# Epoch 56/100
# 390/390 [==============================] - 9s 22ms/step - loss: 0.3114 - acc: 0.8961 - val_loss: 0.6129 - val_acc: 0.8309
# Epoch 57/100
# 390/390 [==============================] - 9s 22ms/step - loss: 0.3129 - acc: 0.8957 - val_loss: 0.5723 - val_acc: 0.8300
# Epoch 58/100
# 390/390 [==============================] - 9s 22ms/step - loss: 0.3093 - acc: 0.8978 - val_loss: 0.5568 - val_acc: 0.8311
# Epoch 59/100
# 390/390 [==============================] - 9s 22ms/step - loss: 0.3107 - acc: 0.8990 - val_loss: 0.5789 - val_acc: 0.8284
# Epoch 60/100
# 390/390 [==============================] - 9s 22ms/step - loss: 0.3070 - acc: 0.8982 - val_loss: 0.5782 - val_acc: 0.8292
# Epoch 61/100
# 390/390 [==============================] - 9s 22ms/step - loss: 0.3050 - acc: 0.8988 - val_loss: 0.5929 - val_acc: 0.8265
# Epoch 62/100
# 390/390 [==============================] - 9s 22ms/step - loss: 0.2937 - acc: 0.9023 - val_loss: 0.5758 - val_acc: 0.8263
# Epoch 63/100
# 390/390 [==============================] - 9s 22ms/step - loss: 0.2954 - acc: 0.9017 - val_loss: 0.5682 - val_acc: 0.8327
# Epoch 64/100
# 390/390 [==============================] - 9s 22ms/step - loss: 0.3010 - acc: 0.9004 - val_loss: 0.5675 - val_acc: 0.8311
# Epoch 65/100
# 390/390 [==============================] - 9s 22ms/step - loss: 0.3026 - acc: 0.9013 - val_loss: 0.5823 - val_acc: 0.8353
# Epoch 66/100
# 390/390 [==============================] - 9s 22ms/step - loss: 0.2977 - acc: 0.9033 - val_loss: 0.5750 - val_acc: 0.8224
# Epoch 67/100
# 390/390 [==============================] - 9s 22ms/step - loss: 0.2914 - acc: 0.9045 - val_loss: 0.5970 - val_acc: 0.8280
# Epoch 68/100
# 390/390 [==============================] - 9s 22ms/step - loss: 0.2873 - acc: 0.9055 - val_loss: 0.6193 - val_acc: 0.8244
# Epoch 69/100
# 390/390 [==============================] - 9s 22ms/step - loss: 0.3020 - acc: 0.9015 - val_loss: 0.5728 - val_acc: 0.8235
# Epoch 70/100
# 390/390 [==============================] - 9s 22ms/step - loss: 0.2912 - acc: 0.9049 - val_loss: 0.5795 - val_acc: 0.8322
# Epoch 71/100
# 390/390 [==============================] - 9s 22ms/step - loss: 0.2863 - acc: 0.9057 - val_loss: 0.5796 - val_acc: 0.8321
# Epoch 72/100
# 390/390 [==============================] - 9s 22ms/step - loss: 0.2861 - acc: 0.9082 - val_loss: 0.5949 - val_acc: 0.8326
# Epoch 73/100
# 390/390 [==============================] - 9s 22ms/step - loss: 0.2956 - acc: 0.9050 - val_loss: 0.5870 - val_acc: 0.8275
# Epoch 74/100
# 390/390 [==============================] - 9s 22ms/step - loss: 0.2863 - acc: 0.9076 - val_loss: 0.5945 - val_acc: 0.8300
# Epoch 75/100
# 390/390 [==============================] - 9s 22ms/step - loss: 0.2812 - acc: 0.9079 - val_loss: 0.5749 - val_acc: 0.8320
# Epoch 76/100
# 390/390 [==============================] - 9s 22ms/step - loss: 0.2901 - acc: 0.9052 - val_loss: 0.5733 - val_acc: 0.8344
# Epoch 77/100
# 390/390 [==============================] - 9s 22ms/step - loss: 0.2723 - acc: 0.9103 - val_loss: 0.6063 - val_acc: 0.8318
# Epoch 78/100
# 390/390 [==============================] - 9s 22ms/step - loss: 0.2722 - acc: 0.9113 - val_loss: 0.5957 - val_acc: 0.8351
# Epoch 79/100
# 390/390 [==============================] - 9s 22ms/step - loss: 0.2772 - acc: 0.9109 - val_loss: 0.5945 - val_acc: 0.8296
# Epoch 80/100
# 390/390 [==============================] - 9s 22ms/step - loss: 0.2840 - acc: 0.9076 - val_loss: 0.5977 - val_acc: 0.8294
# Epoch 81/100
# 390/390 [==============================] - 9s 22ms/step - loss: 0.2792 - acc: 0.9100 - val_loss: 0.6110 - val_acc: 0.8279
# Epoch 82/100
# 390/390 [==============================] - 9s 22ms/step - loss: 0.2805 - acc: 0.9082 - val_loss: 0.6029 - val_acc: 0.8254
# Epoch 83/100
# 390/390 [==============================] - 9s 22ms/step - loss: 0.2808 - acc: 0.9108 - val_loss: 0.6028 - val_acc: 0.8300
# Epoch 84/100
# 390/390 [==============================] - 9s 22ms/step - loss: 0.2766 - acc: 0.9099 - val_loss: 0.6000 - val_acc: 0.8351
# Epoch 85/100
# 390/390 [==============================] - 9s 22ms/step - loss: 0.2682 - acc: 0.9125 - val_loss: 0.6491 - val_acc: 0.8146
# Epoch 86/100
# 390/390 [==============================] - 9s 22ms/step - loss: 0.2819 - acc: 0.9109 - val_loss: 0.5879 - val_acc: 0.8275
# Epoch 87/100
# 390/390 [==============================] - 9s 22ms/step - loss: 0.2658 - acc: 0.9155 - val_loss: 0.6202 - val_acc: 0.8310
# Epoch 88/100
# 390/390 [==============================] - 9s 22ms/step - loss: 0.2710 - acc: 0.9130 - val_loss: 0.6014 - val_acc: 0.8317
# Epoch 89/100
# 390/390 [==============================] - 9s 22ms/step - loss: 0.2736 - acc: 0.9127 - val_loss: 0.5918 - val_acc: 0.8356
# Epoch 90/100
# 390/390 [==============================] - 9s 22ms/step - loss: 0.2696 - acc: 0.9136 - val_loss: 0.6106 - val_acc: 0.8298
# Epoch 91/100
# 390/390 [==============================] - 9s 22ms/step - loss: 0.2674 - acc: 0.9134 - val_loss: 0.5905 - val_acc: 0.8318
# Epoch 92/100
# 390/390 [==============================] - 9s 22ms/step - loss: 0.2639 - acc: 0.9148 - val_loss: 0.5785 - val_acc: 0.8313
# Epoch 93/100
# 390/390 [==============================] - 9s 22ms/step - loss: 0.2730 - acc: 0.9134 - val_loss: 0.5906 - val_acc: 0.8341
# Epoch 94/100
# 390/390 [==============================] - 9s 22ms/step - loss: 0.2774 - acc: 0.9122 - val_loss: 0.6147 - val_acc: 0.8272
# Epoch 95/100
# 390/390 [==============================] - 9s 22ms/step - loss: 0.2636 - acc: 0.9152 - val_loss: 0.5910 - val_acc: 0.8318
# Epoch 96/100
# 390/390 [==============================] - 9s 22ms/step - loss: 0.2607 - acc: 0.9176 - val_loss: 0.6196 - val_acc: 0.8316
# Epoch 97/100
# 390/390 [==============================] - 9s 22ms/step - loss: 0.2646 - acc: 0.9166 - val_loss: 0.6092 - val_acc: 0.8372
# Epoch 98/100
# 390/390 [==============================] - 9s 22ms/step - loss: 0.2591 - acc: 0.9182 - val_loss: 0.5912 - val_acc: 0.8310
# Epoch 99/100
# 390/390 [==============================] - 9s 22ms/step - loss: 0.2724 - acc: 0.9156 - val_loss: 0.6162 - val_acc: 0.8292
# Epoch 100/100
# 390/390 [==============================] - 9s 22ms/step - loss: 0.2688 - acc: 0.9166 - val_loss: 0.6003 - val_acc: 0.8346
# Model took 875.05 seconds to train
# Accuracy on test data is: 83.46

# %% [markdown]
# ###Base Training Accuracy = 91.66
#
# ###Base validation accuracy = 83.46

# %%
# New Architecture
model = Sequential()
model.add(Convolution2D(48, 3, 3, border_mode ='same', input_shape=(32, 32, 3)))#3
model.add(Activation('relu'))
model.add(BatchNormalization())
model.add(Dropout(0.1))

model.add(Convolution2D(96, 3, 3, border_mode ='same')) #5
model.add(Activation('relu'))
model.add(BatchNormalization())
model.add(Dropout(0.1))

model.add(Convolution2D(10, 1, 1, border_mode ='same', activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2))) #10
model.add(BatchNormalization())
#model.add(Dropout(0.25))

model.add(Convolution2D(48, 3, 3, border_mode ='same')) #12
model.add(Activation('relu'))
model.add(BatchNormalization())
model.add(Dropout(0.1))

model.add(Convolution2D(96, 3, 3, border_mode ='same')) #14
model.add(Activation('relu'))
model.add(BatchNormalization())
model.add(Dropout(0.1))

model.add(Convolution2D(10, 1, 1, border_mode ='same', activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2))) #28
model.add(BatchNormalization())
#model.add(Dropout(0.25))

model.add(Convolution2D(48, 3, 3, border_mode ='same')) #30
model.add(Activation('relu'))
model.add(BatchNormalization())
model.add(Dropout(0.1))

model.add(Convolution2D(98, 3, 3, border_mode ='same')) #32
model.add(Activation('relu'))
model.add(BatchNormalization())
model.add(Dropout(0.1))

model.add(Convolution2D(10, 8, 8, activation='relu'))

model.add(Flatten())
model.add(Activation('softmax'))


model.summary()
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:2: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(48, (3, 3), input_shape=(32, 32, 3..., padding="same")`
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:7: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(96, (3, 3), padding="same")`
#   import sys
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:12: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(10, (1, 1), activation="relu", padding="same")`
#   if sys.path[0] == '':
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:17: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(48, (3, 3), padding="same")`
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:22: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(96, (3, 3), padding="same")`
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:27: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(10, (1, 1), activation="relu", padding="same")`
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:32: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(48, (3, 3), padding="same")`
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_52 (Conv2D)           (None, 32, 32, 48)        1344
# _________________________________________________________________
# activation_44 (Activation)   (None, 32, 32, 48)        0
# _________________________________________________________________
# batch_normalization_33 (Batc (None, 32, 32, 48)        192
# _________________________________________________________________
# dropout_44 (Dropout)         (None, 32, 32, 48)        0
# _________________________________________________________________
# conv2d_53 (Conv2D)           (None, 32, 32, 96)        41568
# _________________________________________________________________
# activation_45 (Activation)   (None, 32, 32, 96)        0
# _________________________________________________________________
# batch_normalization_34 (Batc (None, 32, 32, 96)        384
# _________________________________________________________________
# dropout_45 (Dropout)         (None, 32, 32, 96)        0
# _________________________________________________________________
# conv2d_54 (Conv2D)           (None, 32, 32, 10)        970
# _________________________________________________________________
# max_pooling2d_14 (MaxPooling (None, 16, 16, 10)        0
# _________________________________________________________________
# batch_normalization_35 (Batc (None, 16, 16, 10)        40
# _________________________________________________________________
# conv2d_55 (Conv2D)           (None, 16, 16, 48)        4368
# _________________________________________________________________
# activation_46 (Activation)   (None, 16, 16, 48)        0
# _________________________________________________________________
# batch_normalization_36 (Batc (None, 16, 16, 48)        192
# _________________________________________________________________
# dropout_46 (Dropout)         (None, 16, 16, 48)        0
# _________________________________________________________________
# conv2d_56 (Conv2D)           (None, 16, 16, 96)        41568
# _________________________________________________________________
# activation_47 (Activation)   (None, 16, 16, 96)        0
# _________________________________________________________________
# batch_normalization_37 (Batc (None, 16, 16, 96)        384
# _________________________________________________________________
# dropout_47 (Dropout)         (None, 16, 16, 96)        0
# _________________________________________________________________
# conv2d_57 (Conv2D)           (None, 16, 16, 10)        970
# _________________________________________________________________
# max_pooling2d_15 (MaxPooling (None, 8, 8, 10)          0
# _________________________________________________________________
# batch_normalization_38 (Batc (None, 8, 8, 10)          40
# _________________________________________________________________
# conv2d_58 (Conv2D)           (None, 8, 8, 48)          4368
# _________________________________________________________________
# activation_48 (Activation)   (None, 8, 8, 48)          0
# _________________________________________________________________
# batch_normalization_39 (Batc (None, 8, 8, 48)          192
# _________________________________________________________________
# dropout_48 (Dropout)         (None, 8, 8, 48)          0
# _________________________________________________________________
# conv2d_59 (Conv2D)           (None, 8, 8, 98)          42434
# _________________________________________________________________
# activation_49 (Activation)   (None, 8, 8, 98)          0
# _________________________________________________________________
# batch_normalization_40 (Batc (None, 8, 8, 98)          392
# _________________________________________________________________
# dropout_49 (Dropout)         (None, 8, 8, 98)          0
# _________________________________________________________________
# conv2d_60 (Conv2D)           (None, 1, 1, 10)          62730
# _________________________________________________________________
# flatten_7 (Flatten)          (None, 10)                0
# _________________________________________________________________
# activation_50 (Activation)   (None, 10)                0
# =================================================================
# Total params: 202,136
# Trainable params: 201,228
# Non-trainable params: 908
# _________________________________________________________________
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:37: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(98, (3, 3), padding="same")`
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:42: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(10, (8, 8), activation="relu")`

# %%
# Compile the model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
from keras.preprocessing.image import ImageDataGenerator

datagen = ImageDataGenerator(zoom_range=0.0, 
                             horizontal_flip=False)


# train the model
start = time.time()
# Train the model
model_info = model.fit_generator(datagen.flow(train_features, train_labels, batch_size = 512),
                                 samples_per_epoch = train_features.shape[0], nb_epoch = 100, 
                                 validation_data = (test_features, test_labels), verbose=1)
end = time.time()
print ("Model took %0.2f seconds to train"%(end - start))
# plot model history
plot_model_history(model_info)
# compute test accuracy
print ("Accuracy on test data is: %0.2f"%accuracy(test_features, test_labels, model))
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:12: UserWarning: The semantics of the Keras 2 argument `steps_per_epoch` is not the same as the Keras 1 argument `samples_per_epoch`. `steps_per_epoch` is the number of batches to draw from the generator at each epoch. Basically steps_per_epoch = samples_per_epoch/batch_size. Similarly `nb_val_samples`->`validation_steps` and `val_samples`->`steps` arguments have changed. Update your method calls accordingly.
#   if sys.path[0] == '':
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:12: UserWarning: Update your `fit_generator` call to the Keras 2 API: `fit_generator(<keras_pre..., validation_data=(array([[[..., verbose=1, steps_per_epoch=97, epochs=100)`
#   if sys.path[0] == '':
# Epoch 1/100
# 97/97 [==============================] - 21s 213ms/step - loss: 1.8188 - acc: 0.3917 - val_loss: 1.8140 - val_acc: 0.4364
# Epoch 2/100
# 97/97 [==============================] - 17s 179ms/step - loss: 1.3072 - acc: 0.5682 - val_loss: 1.3776 - val_acc: 0.5753
# Epoch 3/100
# 97/97 [==============================] - 16s 168ms/step - loss: 1.0348 - acc: 0.6521 - val_loss: 1.2138 - val_acc: 0.6253
# Epoch 4/100
# 97/97 [==============================] - 16s 167ms/step - loss: 0.8873 - acc: 0.6968 - val_loss: 1.0122 - val_acc: 0.6701
# Epoch 5/100
# 97/97 [==============================] - 16s 167ms/step - loss: 0.7796 - acc: 0.7307 - val_loss: 0.8770 - val_acc: 0.7119
# Epoch 6/100
# 97/97 [==============================] - 16s 167ms/step - loss: 0.6973 - acc: 0.7603 - val_loss: 0.8742 - val_acc: 0.7109
# Epoch 7/100
# 97/97 [==============================] - 16s 168ms/step - loss: 0.6410 - acc: 0.7796 - val_loss: 0.7726 - val_acc: 0.7418
# Epoch 8/100
# 97/97 [==============================] - 16s 168ms/step - loss: 0.5893 - acc: 0.7956 - val_loss: 0.7776 - val_acc: 0.7442
# Epoch 9/100
# 97/97 [==============================] - 16s 168ms/step - loss: 0.5550 - acc: 0.8086 - val_loss: 0.7932 - val_acc: 0.7357
# Epoch 10/100
# 97/97 [==============================] - 16s 167ms/step - loss: 0.5161 - acc: 0.8204 - val_loss: 0.7410 - val_acc: 0.7539
# Epoch 11/100
# 97/97 [==============================] - 16s 167ms/step - loss: 0.4857 - acc: 0.8297 - val_loss: 0.7422 - val_acc: 0.7567
# Epoch 12/100
# 97/97 [==============================] - 16s 167ms/step - loss: 0.4495 - acc: 0.8442 - val_loss: 0.7648 - val_acc: 0.7575
# Epoch 13/100
# 97/97 [==============================] - 16s 168ms/step - loss: 0.4271 - acc: 0.8516 - val_loss: 0.7409 - val_acc: 0.7671
# Epoch 14/100
# 97/97 [==============================] - 16s 167ms/step - loss: 0.4041 - acc: 0.8580 - val_loss: 0.7821 - val_acc: 0.7623
# Epoch 15/100
# 97/97 [==============================] - 16s 167ms/step - loss: 0.3848 - acc: 0.8640 - val_loss: 0.7665 - val_acc: 0.7620
# Epoch 16/100
# 97/97 [==============================] - 16s 167ms/step - loss: 0.3687 - acc: 0.8702 - val_loss: 0.7677 - val_acc: 0.7655
# Epoch 17/100
# 97/97 [==============================] - 16s 167ms/step - loss: 0.3499 - acc: 0.8775 - val_loss: 0.7665 - val_acc: 0.7672
# Epoch 18/100
# 97/97 [==============================] - 16s 167ms/step - loss: 0.3315 - acc: 0.8816 - val_loss: 0.7643 - val_acc: 0.7681
# Epoch 19/100
# 97/97 [==============================] - 16s 167ms/step - loss: 0.3159 - acc: 0.8888 - val_loss: 0.7529 - val_acc: 0.7774
# Epoch 20/100
# 97/97 [==============================] - 16s 168ms/step - loss: 0.3049 - acc: 0.8923 - val_loss: 0.7890 - val_acc: 0.7703
# Epoch 21/100
# 97/97 [==============================] - 16s 167ms/step - loss: 0.2984 - acc: 0.8959 - val_loss: 0.7621 - val_acc: 0.7782
# Epoch 22/100
# 97/97 [==============================] - 16s 168ms/step - loss: 0.2839 - acc: 0.8977 - val_loss: 0.7797 - val_acc: 0.7784
# Epoch 23/100
# 97/97 [==============================] - 16s 167ms/step - loss: 0.2684 - acc: 0.9047 - val_loss: 0.7806 - val_acc: 0.7782
# Epoch 24/100
# 97/97 [==============================] - 16s 167ms/step - loss: 0.2620 - acc: 0.9061 - val_loss: 0.8529 - val_acc: 0.7711
# Epoch 25/100
# 97/97 [==============================] - 16s 167ms/step - loss: 0.2553 - acc: 0.9100 - val_loss: 0.8023 - val_acc: 0.7784
# Epoch 26/100
# 97/97 [==============================] - 16s 167ms/step - loss: 0.2441 - acc: 0.9125 - val_loss: 0.7931 - val_acc: 0.7840
# Epoch 27/100
# 97/97 [==============================] - 16s 167ms/step - loss: 0.2351 - acc: 0.9161 - val_loss: 0.8033 - val_acc: 0.7844
# Epoch 28/100
# 97/97 [==============================] - 16s 167ms/step - loss: 0.2235 - acc: 0.9199 - val_loss: 0.8307 - val_acc: 0.7793
# Epoch 29/100
# 97/97 [==============================] - 16s 167ms/step - loss: 0.2263 - acc: 0.9194 - val_loss: 0.8603 - val_acc: 0.7722
# Epoch 30/100
# 97/97 [==============================] - 16s 167ms/step - loss: 0.2121 - acc: 0.9246 - val_loss: 0.9084 - val_acc: 0.7656
# Epoch 31/100
# 97/97 [==============================] - 16s 168ms/step - loss: 0.2090 - acc: 0.9254 - val_loss: 0.8509 - val_acc: 0.7741
# Epoch 32/100
# 97/97 [==============================] - 16s 167ms/step - loss: 0.2050 - acc: 0.9262 - val_loss: 0.8485 - val_acc: 0.7821
# Epoch 33/100
# 97/97 [==============================] - 16s 167ms/step - loss: 0.2050 - acc: 0.9256 - val_loss: 0.8551 - val_acc: 0.7770
# Epoch 34/100
# 97/97 [==============================] - 16s 167ms/step - loss: 0.1934 - acc: 0.9294 - val_loss: 0.8537 - val_acc: 0.7834
# Epoch 35/100
# 97/97 [==============================] - 16s 167ms/step - loss: 0.1934 - acc: 0.9311 - val_loss: 0.8937 - val_acc: 0.7752
# Epoch 36/100
# 97/97 [==============================] - 16s 167ms/step - loss: 0.1876 - acc: 0.9324 - val_loss: 0.8642 - val_acc: 0.7797
# Epoch 37/100
# 97/97 [==============================] - 16s 167ms/step - loss: 0.1827 - acc: 0.9345 - val_loss: 0.8783 - val_acc: 0.7872
# Epoch 38/100
# 97/97 [==============================] - 16s 168ms/step - loss: 0.1798 - acc: 0.9352 - val_loss: 0.8946 - val_acc: 0.7829
# Epoch 39/100
# 97/97 [==============================] - 16s 167ms/step - loss: 0.1728 - acc: 0.9386 - val_loss: 0.9007 - val_acc: 0.7840
# Epoch 40/100
# 97/97 [==============================] - 16s 168ms/step - loss: 0.1713 - acc: 0.9385 - val_loss: 0.9011 - val_acc: 0.7837
# Epoch 41/100
# 97/97 [==============================] - 16s 168ms/step - loss: 0.1775 - acc: 0.9356 - val_loss: 0.8703 - val_acc: 0.7856
# Epoch 42/100
# 97/97 [==============================] - 16s 168ms/step - loss: 0.1657 - acc: 0.9403 - val_loss: 0.8729 - val_acc: 0.7878
# Epoch 43/100
# 97/97 [==============================] - 16s 168ms/step - loss: 0.1626 - acc: 0.9409 - val_loss: 0.9007 - val_acc: 0.7844
# Epoch 44/100
# 97/97 [==============================] - 16s 168ms/step - loss: 0.1562 - acc: 0.9434 - val_loss: 0.8938 - val_acc: 0.7924
# Epoch 45/100
# 97/97 [==============================] - 16s 168ms/step - loss: 0.1509 - acc: 0.9459 - val_loss: 0.9044 - val_acc: 0.7903
# Epoch 46/100
# 97/97 [==============================] - 16s 168ms/step - loss: 0.1533 - acc: 0.9455 - val_loss: 0.8917 - val_acc: 0.7861
# Epoch 47/100
# 97/97 [==============================] - 16s 167ms/step - loss: 0.1546 - acc: 0.9440 - val_loss: 0.9212 - val_acc: 0.7848
# Epoch 48/100
# 97/97 [==============================] - 16s 167ms/step - loss: 0.1501 - acc: 0.9462 - val_loss: 0.8981 - val_acc: 0.7937
# Epoch 49/100
# 97/97 [==============================] - 16s 168ms/step - loss: 0.1564 - acc: 0.9450 - val_loss: 1.0163 - val_acc: 0.7751
# Epoch 50/100
# 97/97 [==============================] - 16s 167ms/step - loss: 0.1501 - acc: 0.9464 - val_loss: 0.9465 - val_acc: 0.7845
# Epoch 51/100
# 97/97 [==============================] - 16s 167ms/step - loss: 0.1433 - acc: 0.9485 - val_loss: 0.9249 - val_acc: 0.7899
# Epoch 52/100
# 97/97 [==============================] - 16s 167ms/step - loss: 0.1409 - acc: 0.9485 - val_loss: 0.9743 - val_acc: 0.7783
# Epoch 53/100
# 97/97 [==============================] - 16s 168ms/step - loss: 0.1394 - acc: 0.9494 - val_loss: 0.9285 - val_acc: 0.7889
# Epoch 54/100
# 97/97 [==============================] - 16s 167ms/step - loss: 0.1326 - acc: 0.9530 - val_loss: 0.9756 - val_acc: 0.7835
# Epoch 55/100
# 97/97 [==============================] - 16s 167ms/step - loss: 0.1391 - acc: 0.9499 - val_loss: 0.9535 - val_acc: 0.7937
# Epoch 56/100
# 97/97 [==============================] - 16s 168ms/step - loss: 0.1401 - acc: 0.9498 - val_loss: 0.9732 - val_acc: 0.7852
# Epoch 57/100
# 97/97 [==============================] - 16s 167ms/step - loss: 0.1368 - acc: 0.9511 - val_loss: 0.9815 - val_acc: 0.7888
# Epoch 58/100
# 97/97 [==============================] - 16s 167ms/step - loss: 0.1320 - acc: 0.9530 - val_loss: 0.9335 - val_acc: 0.7918
# Epoch 59/100
# 97/97 [==============================] - 16s 167ms/step - loss: 0.1310 - acc: 0.9533 - val_loss: 0.9477 - val_acc: 0.7920
# Epoch 60/100
# 97/97 [==============================] - 16s 167ms/step - loss: 0.1318 - acc: 0.9525 - val_loss: 0.9631 - val_acc: 0.7912
# Epoch 61/100
# 97/97 [==============================] - 16s 167ms/step - loss: 0.1307 - acc: 0.9524 - val_loss: 0.9587 - val_acc: 0.7869
# Epoch 62/100
# 97/97 [==============================] - 16s 167ms/step - loss: 0.1305 - acc: 0.9534 - val_loss: 0.9448 - val_acc: 0.7933
# Epoch 63/100
# 97/97 [==============================] - 16s 168ms/step - loss: 0.1279 - acc: 0.9548 - val_loss: 0.9702 - val_acc: 0.7872
# Epoch 64/100
# 97/97 [==============================] - 16s 167ms/step - loss: 0.1217 - acc: 0.9551 - val_loss: 0.9837 - val_acc: 0.7889
# Epoch 65/100
# 97/97 [==============================] - 16s 167ms/step - loss: 0.1199 - acc: 0.9560 - val_loss: 0.9688 - val_acc: 0.7884
# Epoch 66/100
# 97/97 [==============================] - 16s 168ms/step - loss: 0.1182 - acc: 0.9579 - val_loss: 0.9854 - val_acc: 0.7917
# Epoch 67/100
# 97/97 [==============================] - 16s 167ms/step - loss: 0.1218 - acc: 0.9561 - val_loss: 0.9826 - val_acc: 0.7904
# Epoch 68/100
# 97/97 [==============================] - 16s 167ms/step - loss: 0.1126 - acc: 0.9606 - val_loss: 0.9949 - val_acc: 0.7873
# Epoch 69/100
# 97/97 [==============================] - 16s 167ms/step - loss: 0.1187 - acc: 0.9582 - val_loss: 0.9849 - val_acc: 0.7955
# Epoch 70/100
# 97/97 [==============================] - 16s 168ms/step - loss: 0.1173 - acc: 0.9572 - val_loss: 0.9941 - val_acc: 0.7924
# Epoch 71/100
# 97/97 [==============================] - 16s 167ms/step - loss: 0.1118 - acc: 0.9602 - val_loss: 1.0067 - val_acc: 0.7895
# Epoch 72/100
# 97/97 [==============================] - 16s 167ms/step - loss: 0.1184 - acc: 0.9586 - val_loss: 1.0318 - val_acc: 0.7879
# Epoch 73/100
# 97/97 [==============================] - 16s 167ms/step - loss: 0.1108 - acc: 0.9600 - val_loss: 1.0094 - val_acc: 0.7955
# Epoch 74/100
# 97/97 [==============================] - 16s 167ms/step - loss: 0.1156 - acc: 0.9582 - val_loss: 0.9852 - val_acc: 0.7926
# Epoch 75/100
# 97/97 [==============================] - 16s 168ms/step - loss: 0.1121 - acc: 0.9601 - val_loss: 1.0360 - val_acc: 0.7886
# Epoch 76/100
# 97/97 [==============================] - 16s 168ms/step - loss: 0.1091 - acc: 0.9614 - val_loss: 1.0263 - val_acc: 0.7864
# Epoch 77/100
# 97/97 [==============================] - 16s 167ms/step - loss: 0.1098 - acc: 0.9608 - val_loss: 1.0176 - val_acc: 0.7900
# Epoch 78/100
# 97/97 [==============================] - 16s 168ms/step - loss: 0.1070 - acc: 0.9619 - val_loss: 1.0190 - val_acc: 0.7909
# Epoch 79/100
# 97/97 [==============================] - 16s 168ms/step - loss: 0.1081 - acc: 0.9613 - val_loss: 1.0223 - val_acc: 0.7869
# Epoch 80/100
# 97/97 [==============================] - 16s 167ms/step - loss: 0.1037 - acc: 0.9634 - val_loss: 1.0454 - val_acc: 0.7834
# Epoch 81/100
# 97/97 [==============================] - 16s 167ms/step - loss: 0.1050 - acc: 0.9623 - val_loss: 1.0551 - val_acc: 0.7910
# Epoch 82/100
# 97/97 [==============================] - 16s 167ms/step - loss: 0.1053 - acc: 0.9617 - val_loss: 1.0447 - val_acc: 0.7910
# Epoch 83/100
# 97/97 [==============================] - 16s 167ms/step - loss: 0.1048 - acc: 0.9633 - val_loss: 1.0645 - val_acc: 0.7893
# Epoch 84/100
# 97/97 [==============================] - 16s 167ms/step - loss: 0.1050 - acc: 0.9625 - val_loss: 1.0282 - val_acc: 0.7938
# Epoch 85/100
# 97/97 [==============================] - 16s 168ms/step - loss: 0.1024 - acc: 0.9626 - val_loss: 1.0413 - val_acc: 0.7945
# Epoch 86/100
# 97/97 [==============================] - 16s 167ms/step - loss: 0.1002 - acc: 0.9636 - val_loss: 1.0708 - val_acc: 0.7839
# Epoch 87/100
# 97/97 [==============================] - 16s 167ms/step - loss: 0.1068 - acc: 0.9619 - val_loss: 1.0732 - val_acc: 0.7927
# Epoch 88/100
# 97/97 [==============================] - 16s 167ms/step - loss: 0.1030 - acc: 0.9629 - val_loss: 1.0516 - val_acc: 0.7865
# Epoch 89/100
# 97/97 [==============================] - 16s 167ms/step - loss: 0.1023 - acc: 0.9640 - val_loss: 1.0051 - val_acc: 0.7952
# Epoch 90/100
# 97/97 [==============================] - 16s 167ms/step - loss: 0.0961 - acc: 0.9662 - val_loss: 1.0304 - val_acc: 0.7902
# Epoch 91/100
# 97/97 [==============================] - 16s 167ms/step - loss: 0.0930 - acc: 0.9666 - val_loss: 1.0097 - val_acc: 0.7951
# Epoch 92/100
# 97/97 [==============================] - 16s 168ms/step - loss: 0.0988 - acc: 0.9643 - val_loss: 1.0690 - val_acc: 0.7836
# Epoch 93/100
# 97/97 [==============================] - 16s 167ms/step - loss: 0.0985 - acc: 0.9652 - val_loss: 1.0305 - val_acc: 0.7932
# Epoch 94/100
# 97/97 [==============================] - 16s 167ms/step - loss: 0.0939 - acc: 0.9672 - val_loss: 1.0310 - val_acc: 0.7961
# Epoch 95/100
# 97/97 [==============================] - 16s 167ms/step - loss: 0.0962 - acc: 0.9664 - val_loss: 1.0531 - val_acc: 0.7889
# Epoch 96/100
# 97/97 [==============================] - 16s 167ms/step - loss: 0.0965 - acc: 0.9654 - val_loss: 1.0453 - val_acc: 0.7913
# Epoch 97/100
# 97/97 [==============================] - 16s 168ms/step - loss: 0.0952 - acc: 0.9662 - val_loss: 1.0301 - val_acc: 0.7993
# Epoch 98/100
# 97/97 [==============================] - 17s 171ms/step - loss: 0.0946 - acc: 0.9664 - val_loss: 1.0313 - val_acc: 0.7958
# Epoch 99/100
# 97/97 [==============================] - 16s 168ms/step - loss: 0.0900 - acc: 0.9678 - val_loss: 1.0107 - val_acc: 0.7965
# Epoch 100/100
# 97/97 [==============================] - 16s 167ms/step - loss: 0.0928 - acc: 0.9673 - val_loss: 1.0702 - val_acc: 0.7944
# Model took 1630.99 seconds to train
# Accuracy on test data is: 79.44

# %%
+
